# %% [markdown]
# # How is data science used in fintech.
# A research over 600 world leading fintech companies.

# %% [markdown]
# ## list of companies

# %% [raw]
# Ant Financial
# Adyen
# Qudian
# Xero
# Lufax
# SoFi
# Avant
# ZhongAn
# Klarna
# Oscar
# Action.AI
# AdviceRobo
# Aire
# Algomi
# AQMetrics
# Atom Bank
# Azimo
# Behaviosec
# Bonify
# Clearmatics
# ClearScore
# ComplyAdvantage
# Contego
# CreditBenchmark
# Curve
# Darktrace
# Digital Shadows
# Ethereum
# FeatureSpace
# Fenergo
# Figo
# FundApps
# iwoca
# Kantox
# LendInvest
# Mambu
# MarketInvoice
# Monzo
# N26
# NetGuardians
# Onfido
# OpenGamma
# PayKey
# Qumram
# Railsbank
# Raisin
# RateSetter
# Revolut
# Scalable Capital
# Seedrs
# SETL
# solarisBank
# Suade
# ThoughtMachine
# Traxpay
# Trussle
# wefox
# AlphaSense
# Aztec Exchange
# Cadre
# Chain
# CircleUp
# Coinbase
# Credit Karma
# Digital Reasoning
# Earnest
# EarnUp
# Fundbox
# Funding Circle
# Fundrise
# Gusto
# Kabbage
# Kensho
# Metromile
# Motif Investing
# Numerai
# Personal Capital
# Plaid
# Quantopian
# Ripple
# Riskalyze
# Signifyd
# Stripe
# Tala
# TransferWise
# TrueAccord
# Trumid
# Xignite
# ZestFinance
# Blockchain
# WorldRemit
# Zopa
# Crowdcube
# Nutmeg
# GoCardless
# eToro
# DueDil
# Currency Cloud
# Kreditech
# JD Finance
# Qudian (Qufenqi)
# Nubank
# Square
# SecureKey Technologies
# Affirm
# Clover Health
# Prospa
# OurCrowd
# iZettle
# 51Xinyongka (u51.com)
# OnDeck
# WealthSimple
# Circle
# Dianrong
# Spotcap
# Lendingkart
# Xapo
# Viva Republica
# WeLab
# zipMoney
# Rong360
# Future Finance
# League
# Pushpay
# CompareEuropeGroup
# AfterPay Touch
# Lendix
# Lending Club
# Kueski
# GuiaBolso
# Robinhood
# AimBrain
# Airwallex
# Alan
# AutoGravity
# Banqer
# Borrowell
# Bud
# Capital Float
# Clark Germany GmbH
# Cover Genius
# CoverWallet
# Creamfinance
# Cuvva
# Flutterwave Inc
# GrassRoots Bima
# Hyper Anna
# IbanFirst
# iyzico
# KredX
# Lendify
# Leveris
# Lydia
# Macrovue
# MoneyMe
# Moneytree
# Neo Growth
# Neyber
# PayFit
# Plynk
# Pockit
# Qonto
# Riby
# Satispay
# Sensibill
# Sherpa
# Silent8
# SoCash
# Stash
# TapPay
# ThetaRay
# Tic:Toc
# Token
# Trusona Inc.
# Valiant
# VATBox
# Wave
# Zaveapp
# Avoka
# BioCatch
# Cross River Bank
# Digit
# Dwolla
# Elliptic
# Envestnet | Yodlee
# Ethereum Project
# FastPay
# Flywire
# Google
# Amazon
# Apple
# Facebook
# GreenSky
# Lantern Credit
# Nav
# Paid
# Payoneer
# Paypal
# Venmo
# Personetics
# Point
# PolicyGenius
# Proov
# SmartAsset
# Sourcery
# Stockpile
# trōv
# True Wealth AG
# Advanon AG
# Money Park
# TawiPay
# CashSentinel SA
# Paymit
# Contovista AG
# Qontis AG
# Numbrs
# Vijay Shekhar Sharma
# ItzCash Card
# Naveen Surya
# BankBazaar
# Personal Finance Management
# InCred
# Lending
# Bhupinder Singh
# PolicyBazaar
# Insurance
# Rishi Gupta
# Mswipe Technologies
# Manish Patel
# Electronic Payments and Services
# Mani Mamallan
# NeoGrowth Credit
# CCAvenue
# Paymenxts
# Vishwas Patel
# Coverfox
# FundsIndia
# Flexiloans
# MoneyTap
# Razorpay Software
# MoneyView
# Sanjay Aggarwal
# Chillr
# LoanTap
# ChargeBee Technologies
# Rubique
# Manavjeet Singh
# Juspay
# Faircent
# Early Salary
# Akshay Mehrotra
# IndiaLends
# Upstox
# Online Trading Platform
# AirPay Payment Services
# Instamojo
# SecureNow TechServices
# RedCarpet
# Paynear
# TruPay
# Loan Frame Technologies
# Shailesh Jacob
# Easypolicy
# CreditVidya
# ePaylater
# UnoCoin
# Cryptocurrency
# Fisdom
# RenewBuy
# Zebpay
# 118 118 Money
# 1Plus1 Loans
# 1st Stop
# 1st Stop Home Loans
# AA
# Admiral
# Amigo
# Argos
# Aspire Money
# AvantCredit
# Bamboo
# Bank of Ireland
# Bank of Scotland
# Barclays
# besavvi
# Buddy Loans
# Cahoot
# CarFinance 247
# Central Trust Ltd
# Citrus Loans
# Clearly Loans
# Clydesdale Bank
# Creation
# Creditplus
# Danske Bank
# EDF Energy
# Equifinance
# Everydayloans
# findme car finance
# First Direct
# Guarantor My Loan
# Halifax
# Hitachi
# HSBC
# Ikano Bank
# John Lewis and Waitrose Partnership
# Juo Loans
# JustUs
# Lendable
# Lending Works
# Likely Loans
# Lloyds Bank
# M&S Bank
# MASA Loans
# Masthaven
# Metro Bank
# Midland Credit
# My Community Bank
# Nationwide
# NatWest
# Norton Finance
# Oakam
# Ocean Finance
# On Stride Financial
# Opal Loans
# Paragon Personal Finance
# Places for People Financial Services
# Post Office
# Prestige Finance
# Progressive Money
# QuidCycle
# RAC
# Royal Bank of Scotland
# Saga
# Sainsbury's Bank
# Santander
# Shawbrook Bank
# Smile
# Spring Finance
# Step One Finance
# Suco
# Tesco Bank
# TFS Loans
# The Co-operative Bank
# Together
# Trusttwo
# TSB
# UK Credit
# Ulster Bank
# United Trust Bank
# Very
# Wesleyan Bank
# Whatcredit
# Yorkshire Bank
# Zuto

# %%
"""
========
Barchart
========

A bar plot with errorbars and height labels on individual bars
"""
import numpy as np
import matplotlib.pyplot as plt

N = 1
men_means = (310)
men_std = (2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)

women_means = (6000)
women_std = (3)
rects2 = ax.bar(ind + width, women_means, width, color='y', yerr=women_std)

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('G1'))

ax.legend((rects1[0], rects2[0]), ('total', 'published data'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %% [markdown]
# ## list of companies with publication

# %% [raw]
# 1st Stop Home Loans
# 1st Stop
# 51Xinyongka (u51.com)
# 51Xinyongka
# Acorns
# Addepar
# Admiral
# AdviceRobo
# Adyen
# Affirm
# Akshay Mehrotra
# Alan
# AlphaSense
# Amigo
# Ant Financial
# Apple
# AQMetrics
# Argos
# Artivest Holdings
# Assembly Payments
# AutoGravity
# Auxmoney
# Avalara
# Avant
# AvantCredit
# Avoka
# Axoni
# Aztec Exchange
# Bamboo
# Bank of Scotland
# Banqer
# Barclays
# Behaviosec
# besavvi
# Better Mortgage
# Betterment
# BIMA
# BioCatch
# BitPesa
# Blend
# Blockstack Labs
# Blockstream
# Bonify
# Borrowell
# Branch International
# Brave Software
# Bright Health
# Bud
# C2FO
# Cadre
# Cahoot
# Capital Float
# Captable.io
# CarFinance 247
# Chillr
# Circle Internet Financial
# Circle
# CircleUp
# Citrus Loans
# Clarity Money
# Clark Germany GmbH
# Cloud9 Technologies
# Clover Health
# Coinbase
# Coins.ph
# ComplyAdvantage
# Contego
# Cover Genius
# Coverfox
# CoverWallet
# Creamfinance
# Creation
# Credit Benchmark
# Credit Karma
# CreditBenchmark
# CreditMantri
# CreditVidya
# Cross River Bank
# Crowdcube
# Currency Cloud
# Curve
# Cuvva
# Cyence
# Dadao Financial
# Danske Bank
# Darktrace
# Deposit Solutions
# Dianrong
# Digit
# Digital Reasoning
# Digital Shadows
# Droit Fintech
# DueDil
# Dwolla
# Earnest
# Easypolicy
# EDF Energy
# Embroker
# ePaylater
# eShares
# Ethereum Project
# Ethereum Switzerland GmbH
# Ethereum
# eToro
# Facebook
# Factom
# FeatureSpace
# Fenergo
# Fenqile
# FinanceIt
# FinancialForce.com
# Finrise
# First Direct
# Flexiloans
# freee
# Funding Circle
# Funding Societies
# Fundrise
# Future Finance
# Google
# GrassRoots Bima
# GreenSky
# Guarantor My Loan
# Gusto
# Halifax
# hibob
# Hitachi
# HSBC
# Hyper Anna
# IbanFirst
# IEX Group
# Ikano Bank
# InCred
# IndiaLends
# Indifi Technologies
# Instamojo
# Insurance
# Investglass SA
# iwoca
# iyzico
# iZettle
# Juspay
# JustUs
# Kabbage
# Kakao Pay
# Kantox
# Kasisto
# Kensho Technologies
# Kensho
# Kickstarter
# Klarna
# Kreditech
# KredX
# Kueski
# Kyriba
# Ladder
# Lantern Credit
# League
# Lemonade
# Lendify
# Lending Works
# Lending
# LendingHome
# LendInvest
# Lendix
# LendUp
# LevelUp
# Likely Loans
# Lloyds Bank
# LoanTap
# Lu.com
# Macrovue
# Mambu
# Manavjeet Singh
# Mani Mamallan
# Marqeta
# Merlon Intelligence
# Metro Bank
# Metromile
# Midland Credit
# MobiKwik
# MoneyFarm
# Moneytree
# Monzo
# Motif Investing
# NatWest
# Nav
# Naveen Surya
# Neighborly
# Neo Growth
# Numbrs
# Nutmeg
# Ocean Finance
# On Stride Financial
# OnDeck
# Onfido
# OpenFin
# Oportun
# Oscar Health Insurance Co.
# Oscar
# OurCrowd
# Paga
# Parasut
# PayFit
# Paynear
# PayNearMe
# Payoneer
# Paypal
# Paytm Payment Bank
# PeerIQ
# PeerStreet
# Personal Capital
# Personal Finance Management
# Personetics
# Ping++
# Point
# PolicyBazaar
# Post Office
# Proov
# Propel
# Prospa
# Pushpay
# Qapital Insight
# QFPay
# Quantopian
# Qudian (Qufenqi)
# Qudian
# QuidCycle
# Qumram AG
# Qumram
# Quovo
# RealtyShares
# Red Dot Payment
# Revolut
# Riby
# Ripple Labs
# Ripple
# Robinhood
# Rong360
# Roofstock
# Royal Bank of Scotland
# Rubique
# Sanjay Aggarwal
# Santander
# Satispay
# Scalable Capital
# SecureKey Technologies
# Seedrs
# Sensibill
# SETL
# Signifyd
# Silent8
# Silverfin
# simplesurance
# SirionLabs
# Smile
# SoFi
# solarisBank
# Sourcery
# Splendit
# Spotcap
# Square
# Stockpile
# Street Contxt
# Stripe
# Suade
# Tesco Bank
# TFS Loans
# ThetaRay
# ThoughtMachine
# Tink
# Token
# TransferWise
# TravelBank
# Traxpay
# Trov
# True Wealth AG
# Trulioo
# Trumid
# TruPay
# Trusona Inc.
# UK Credit
# Ulster Bank
# Upstox
# Very
# Wave
# WealthNavi
# Wealthport AG
# WealthSimple
# WeCash
# wefox
# WeLab
# Wesleyan Bank
# WorldCover
# WorldRemit
# Xapo
# Xero
# Xignite
# Xishan Information Technology
# Yoco
# Yorkshire Bank
# Zaveapp
# ZestFinance
# Zhong An Insurance
# ZhongAn
# zipMoney
# Zoona
# Zooz
# Zopa

# %%
import pandas as pd
df = pd.read_csv('/var/www/findings.csv')

def normalize(str):
    if type(str) is float:
        return '-'
    return str

def normalize_column(col_header):
    df[col_header] = df[col_header].apply(lambda x: normalize(x)) 

for c in df.columns:
    normalize_column(c)

df
# Out:
#                  Company name Data Visualization Credit risk Fraud  \
# 0                        Zopa                yes         yes     -
# 1          Zhong An Insurance                  -           -     -
# 2                 ZestFinance                  -         yes     -
# 3                      WeCash                  -         yes     -
# 4                WealthSimple                  -           -     -
# 5                  WealthNavi                  -           -     -
# 6                  Kreditech�                  -         yes     -
# 7                  TravelBank                  -           -     -
# 8                    ThetaRay                  -           -     -
# 9                       Suade                  -         yes     -
# 10                     Stripe                  -           -   yes
# 11              Street Contxt                  -           -     -
# 12                       SoFi                  -         yes     -
# ...

# %% [markdown]
# ## statistics

# %%
frequency_table = dict()

def process_column(col_header):
    frequency_table[col_header] = 0
    df[col_header] = df[col_header].apply(lambda x: count(x, col_header))


def count(str, col_header):
    if str == 'yes':
        frequency_table[col_header] = frequency_table[col_header] + 1 
    return str

for c in df.columns:
    if not c == 'Company name':
        process_column(c)

# %%
N = len(frequency_table.keys())
labels = frequency_table.keys()
sizes = [frequency_table[k] for k in frequency_table.keys()]
explode = (0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(7, 7))
patches, texts, autotexts = ax1.pie(sizes,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
for t in  texts:
    t.set_fontsize(14)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
stats = df.describe()
stats
# Out:
#          Company name Data Visualization Credit risk Fraud  \
# count              31                 31          31    31
# unique             31                  2           2     2
# top     Street Contxt                  -           -     -
# freq                1                 29          17    26
#
#        Marketing Campaign Analysis Pricing Chatbots Financial Advise  \
# count                           31      31       31               31
# unique                           2       2        2                2
# top                              -       -        -                -
# freq                            29      30       28               27
#
#        Anomaly detection Classification (customer, content) Customer Service
# count                 31                                 31               31
# unique                 2                                  2                2
# top                    -                                  -                -
# ...
